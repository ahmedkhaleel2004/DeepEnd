# %%
import pandas as pd

# Load the CSV data into a pandas DataFrame
data = pd.read_csv('repositories.csv')

# Display the first few rows of the DataFrame
data.head()
# Out:
#                           Name  \
# 0                 freeCodeCamp
# 1       free-programming-books
# 2                      awesome
# 3                      996.ICU
# 4  coding-interview-university
#
#                                          Description  \
# 0  freeCodeCamp.org's open-source codebase and cu...
# 1         :books: Freely available programming books
# 2  😎 Awesome lists about all kinds of interesting...
# 3  Repo for counting stars and contributing. Pres...
# 4  A complete computer science study plan to beco...
#
#                                                  URL            Created At  \
# 0       https://github.com/freeCodeCamp/freeCodeCamp  2014-12-24T17:49:19Z
# 1  https://github.com/EbookFoundation/free-progra...  2013-10-11T06:50:37Z
# 2            https://github.com/sindresorhus/awesome  2014-07-11T13:42:37Z
# 3                  https://github.com/996icu/996.ICU  2019-03-26T07:31:14Z
# 4  https://github.com/jwasham/coding-interview-un...  2016-06-06T02:34:12Z
#
#              Updated At                                           Homepage  \
# 0  2023-09-21T11:32:33Z                http://contribute.freecodecamp.org/
# 1  2023-09-21T11:09:25Z  https://ebookfoundation.github.io/free-program...
# 2  2023-09-21T11:18:22Z                                                NaN
# 3  2023-09-21T08:09:01Z                                    https://996.icu
# 4  2023-09-21T10:54:48Z                                                NaN
#
#      Size   Stars  Forks  Issues  ...  Has Issues Has Projects Has Downloads  \
# 0  387451  374074  33599     248  ...        True         True          True
# 1   17087  298393  57194      46  ...        True        False          True
# 2    1441  269997  26485      61  ...        True        False          True
# 3  187799  267901  21497   16712  ...       False        False          True
# 4   20998  265161  69434      56  ...        True        False          True
#
#   Has Wiki  Has Pages  Has Discussions  Is Fork  Is Archived  Is Template  \
# 0    False       True            False    False        False        False
# 1    False       True            False    False        False        False
# 2    False       True            False    False        False        False
# 3    False      False            False    False         True        False
# 4    False      False            False    False        False        False
#
#    Default Branch
# 0            main
# 1            main
# 2            main
# 3          master
# 4            main
#
# [5 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['Name', 'Description', 'URL', 'Created At', 'Updated At', 'Homepage',
#        'Size', 'Stars', 'Forks', 'Issues', 'Watchers', 'Language', 'License',
#        'Topics', 'Has Issues', 'Has Projects', 'Has Downloads', 'Has Wiki',
#        'Has Pages', 'Has Discussions', 'Is Fork', 'Is Archived', 'Is Template',
#        'Default Branch'],
#       dtype='object')

# %%
columns_to_keep = ['Name', 'Description', 'Stars', 'Language', 'Topics']
if all(col in data.columns for col in columns_to_keep):
    data = data[columns_to_keep]
else:
    print("One or more columns do not exist in the DataFrame.")

# %%
data.head()
# Out:
#                           Name  \
# 0                 freeCodeCamp
# 1       free-programming-books
# 2                      awesome
# 3                      996.ICU
# 4  coding-interview-university
#
#                                          Description   Stars    Language  \
# 0  freeCodeCamp.org's open-source codebase and cu...  374074  TypeScript
# 1         :books: Freely available programming books  298393         NaN
# 2  😎 Awesome lists about all kinds of interesting...  269997         NaN
# 3  Repo for counting stars and contributing. Pres...  267901         NaN
# 4  A complete computer science study plan to beco...  265161         NaN
#
#                                               Topics
# 0  ['careers', 'certification', 'community', 'cur...
# 1  ['books', 'education', 'hacktoberfest', 'list'...
# 2  ['awesome', 'awesome-list', 'lists', 'resource...
# 3                                                 []
# 4  ['algorithm', 'algorithms', 'coding-interview'...

# %%
data.dropna(inplace=True)
data.head()
# Out:
#                    Name                                        Description  \
# 0          freeCodeCamp  freeCodeCamp.org's open-source codebase and cu...
# 5           public-apis                     A collective list of free APIs
# 6     developer-roadmap  Interactive roadmaps, guides and other educati...
# 7  system-design-primer  Learn how to design large-scale systems. Prep ...
# 9                 react     The library for web and native user interfaces
#
#     Stars    Language                                             Topics
# 0  374074  TypeScript  ['careers', 'certification', 'community', 'cur...
# 5  256615      Python  ['api', 'apis', 'dataset', 'development', 'fre...
# 6  251416  TypeScript  ['angular-roadmap', 'backend-roadmap', 'blockc...
# 7  229569      Python  ['design', 'design-patterns', 'design-system',...
# 9  213299  JavaScript  ['declarative', 'frontend', 'javascript', 'lib...

# %%
data.iloc[23451]
# Out:
# Name                      webpack-visualizer
# Description    Visualize your Webpack bundle
# Stars                                   1685
# Language                          JavaScript
# Topics         ['webpack', 'webpack-plugin']
# Name: 25927, dtype: object

# %%
data.head()
# Out:
#                    Name                                        Description  \
# 0          freeCodeCamp  freeCodeCamp.org's open-source codebase and cu...
# 5           public-apis                     A collective list of free APIs
# 6     developer-roadmap  Interactive roadmaps, guides and other educati...
# 7  system-design-primer  Learn how to design large-scale systems. Prep ...
# 9                 react     The library for web and native user interfaces
#
#     Stars    Language                                             Topics
# 0  374074  TypeScript  ['careers', 'certification', 'community', 'cur...
# 5  256615      Python  ['api', 'apis', 'dataset', 'development', 'fre...
# 6  251416  TypeScript  ['angular-roadmap', 'backend-roadmap', 'blockc...
# 7  229569      Python  ['design', 'design-patterns', 'design-system',...
# 9  213299  JavaScript  ['declarative', 'frontend', 'javascript', 'lib...

# %%
#time for some feature engineering
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder

# %%
# NLP processing for 'Description'
tfidf = TfidfVectorizer(max_features=100)  # Adjust parameters as needed
description_features = tfidf.fit_transform(data['Description'])

# %%
# One-hot encoding for 'Language'
encoder = OneHotEncoder()
language_features = encoder.fit_transform(data[['Language']])

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalizing 'Stars'
scaler = MinMaxScaler()
stars_features = scaler.fit_transform(data[['Stars']])

# %%
# Assuming 'Topics' is a list of topics in string format, like "['topic1', 'topic2', ...]"
import ast  # For safely evaluating the string representation of a list

# Convert the string representation of lists into actual lists
data['Topics'] = data['Topics'].apply(ast.literal_eval)

# Join the topics into a single string per entry
data['Topics_joined'] = data['Topics'].apply(lambda x: ' '.join(x))

# NLP processing for 'Topics'
tfidf_topics = TfidfVectorizer(max_features=100)  # You can adjust the parameters
topics_features = tfidf_topics.fit_transform(data['Topics_joined'])

# %%
import scipy.sparse as sp

# Combine all features into one dataset
all_features = sp.hstack([description_features, language_features, stars_features, topics_features])

# Convert to a format suitable for training (e.g., to a dense array if the dataset is not too large)
all_features_dense = all_features.toarray()

# %% [markdown]
# #### Prepare labels?
#
# Only needed for supervised models!

# %%
from sklearn.metrics.pairwise import cosine_similarity

user_input = ""
user_input_processed = tfidf.transform([user_input])

N = 10

# Calculate similarity
similarity_scores = cosine_similarity(user_input_processed, description_features)  # Assuming 'description_features' is your repository feature matrix

# Get top N similar repositories
top_n_indices = similarity_scores.argsort()[0][-N:]  # Replace N with the number of recommendations you want
top_n_repos = data.iloc[top_n_indices]
top_n_repos
# Out:
#                        Name  \
# 80261        SQuAD-explorer
# 160563           bl_iot_sdk
# 36837                  Tomb
# 175145                  csm
# 11971   genshin-wish-export
# 62169           mongo-spark
# 154916           CSSans.Pro
# 85087                  btpd
# 62105               prjxray
# 156932               sakila
#
#                                               Description  Stars    Language  \
# 80261   Visually Explore the Stanford Question Answeri...    521  JavaScript
# 160563  BL602/BL702 SDK. Any technical topic, please a...    238           C
# 36837                               the Crypto Undertaker   1195       Shell
# 175145                      The C(canonical) Scan Matcher    214           C
# 11971       Easily export the Genshin Impact wish record.   3438  JavaScript
# 62169                         The MongoDB Spark Connector    685        Java
# 154916        CSSans Pro - The Colourful, Sassy, CSS Font    248  JavaScript
# 85087                    ⚡ The BitTorrent Protocol Daemon    488           C
# 62105   Documenting the Xilinx 7-series bit-stream for...    685      Python
# 156932                                The Sakila Database    245     PLpgSQL
#
#                                                    Topics  \
# 80261             [dataset, leaderboard, visual-analysis]
# 160563  [aiot, bl602, bl60x, bl702, bl706, bl70x, ble,...
# 36837   [crypto, dyne, encryption, files, filesystem, ...
# 175145                                                 []
# 11971                           [genshin, genshin-impact]
# 62169   [connector, mongo-spark, mongodb, spark, spark...
# 154916                           [css, cssans, font, pro]
# 85087                    [bittorrent, c, daemon, torrent]
# 62105   [artix, artix7, bitstream, fpga, fuzzer, kinte...
# 156932                                                 []
#
#                                             Topics_joined
# 80261                 dataset leaderboard visual-analysis
# 160563  aiot bl602 bl60x bl702 bl706 bl70x ble bouffal...
# 36837   crypto dyne encryption files filesystem keys l...
# 175145
# 11971                              genshin genshin-impact
# 62169   connector mongo-spark mongodb spark spark-pack...
# 154916                                css cssans font pro
# 85087                         bittorrent c daemon torrent
# 62105   artix artix7 bitstream fpga fuzzer kintex7 sym...
# 156932
